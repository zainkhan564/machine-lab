# %% [markdown]
# ### Introduction To Pandas Module
# Here, we are learning data analysis. Pandas is a software library written for the Python programming language that helps with data manipulation and analysis. It offers various data structures which help in the manipulation of data. <br>
# One of the data structures used is DataFrame.<br>
# DataFrame is used as a way to store data in a rectangular grid.<br>
# Similar to how data is stored in Microsoft Excel.
# ### Installation
# We can easily install this library using the terminal. Follow the steps given below to install Pandas:<br>
# Step 1: Go to the Windows PowerShell.<br>
# Step 2: We can install pandas with the help of pip easily. Head over to the directory where you want to install the pandas and fire the below command:<br>
# __pip install pandas__<br>
# This is very simple to install.

# %%
# !pip install pandas

# %% [markdown]
# ### Other way to install
# If the above steps do not work for you, here is another way to install:<br>
# Step 1: Go to your browser. Search for __python unofficial binaries__, or click <br>
# https://www.lfd.uci.edu/~gohlke/pythonlibs/<br>
# and you will be redirected to the binary page.<br>
# Step 2: To download the library, search for pandas – Ctrl + F will help you. Download pandas library based on your python version. <br>
# Step 3: After the installation, head over to the directory where you've downloaded the pandas. <br>
# Step 4: Right-click to open Windows PowerShell. Pip can help us with the installation. Just go to that location in your terminal and run the following command: <br>
# __pip install pandas__ <br>
# Complete this command by the TAB button so that the location of your folder is mentioned.

# %% [markdown]
# ### import pandas
# Once Pandas is installed, import it in your applications by adding the import keyword:<br>
# __import pandas as pd__<br>
# Now Pandas is imported and ready to use.

# %%
import pandas as pd

# %%
dict1 = {
    'Name': ["Ahmed Khan", "Fatima Noor", "Mohammad Ali", "Ayesha Siddiq",
             "Hassan Raza","Zainab Sheikh","Umar Farooq","Maryam Bibi",
             "Bilal Saeed","Khadija Rehman","Yusuf Jamal","Hafsa Tariq",
             "Ibrahim Zaid","Nimra Shah","Suleman Iqbal"],


    'Registration Number': ["21jzele04230","21jzele04231","21jzele04232","21jzele04233","21jzele04234",
                             "21jzele04235","21jzele04236","21jzele04237","21jzele04238","21jzele04239",
                             "21jzele04240","21jzele04241","21jzele04242","21jzele04243","21jzele04244"],


    'GPA':["3.22","2.15","2.74","3.34","2.8","2.6","3.61","3.25","2.14","2.15","2.01","2.33",
           "2.15","2.07","3.3"]
}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#               Name Registration Number   GPA
# 0       Ahmed Khan        21jzele04230  3.22
# 1      Fatima Noor        21jzele04231  2.15
# 2     Mohammad Ali        21jzele04232  2.74
# 3    Ayesha Siddiq        21jzele04233  3.34
# 4      Hassan Raza        21jzele04234   2.8
# 5    Zainab Sheikh        21jzele04235   2.6
# 6      Umar Farooq        21jzele04236  3.61
# 7      Maryam Bibi        21jzele04237  3.25
# 8      Bilal Saeed        21jzele04238  2.14
# 9   Khadija Rehman        21jzele04239  2.15
# 10     Yusuf Jamal        21jzele04240  2.01
# 11     Hafsa Tariq        21jzele04241  2.33
# 12    Ibrahim Zaid        21jzele04242  2.15
# 13      Nimra Shah        21jzele04243  2.07
# 14   Suleman Iqbal        21jzele04244   3.3

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#               Name Registration Number   GPA
# 0       Ahmed Khan        21jzele04230  3.22
# 1      Fatima Noor        21jzele04231  2.15
# 2     Mohammad Ali        21jzele04232  2.74
# 3    Ayesha Siddiq        21jzele04233  3.34
# 4      Hassan Raza        21jzele04234   2.8
# 5    Zainab Sheikh        21jzele04235   2.6
# 6      Umar Farooq        21jzele04236  3.61
# 7      Maryam Bibi        21jzele04237  3.25
# 8      Bilal Saeed        21jzele04238  2.14
# 9   Khadija Rehman        21jzele04239  2.15
# 10     Yusuf Jamal        21jzele04240  2.01
# 11     Hafsa Tariq        21jzele04241  2.33
# 12    Ibrahim Zaid        21jzele04242  2.15
# 13      Nimra Shah        21jzele04243  2.07
# 14   Suleman Iqbal        21jzele04244   3.3

# %% [markdown]
# ### Pandas as pd
# Pandas is usually imported under the pd alias.
# #### alias:
# In Python alias are an alternate name for referring to the same thing.<br>
# Create an alias with the as keyword while importing:<br>
# __import pandas as pd__<br>
# Now the Pandas package can be referred to as pd instead of pandas.

# %%
import pandas as pd

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#               Name Registration Number   GPA
# 0       Ahmed Khan        21jzele04230  3.22
# 1      Fatima Noor        21jzele04231  2.15
# 2     Mohammad Ali        21jzele04232  2.74
# 3    Ayesha Siddiq        21jzele04233  3.34
# 4      Hassan Raza        21jzele04234   2.8
# 5    Zainab Sheikh        21jzele04235   2.6
# 6      Umar Farooq        21jzele04236  3.61
# 7      Maryam Bibi        21jzele04237  3.25
# 8      Bilal Saeed        21jzele04238  2.14
# 9   Khadija Rehman        21jzele04239  2.15
# 10     Yusuf Jamal        21jzele04240  2.01
# 11     Hafsa Tariq        21jzele04241  2.33
# 12    Ibrahim Zaid        21jzele04242  2.15
# 13      Nimra Shah        21jzele04243  2.07
# 14   Suleman Iqbal        21jzele04244   3.3

# %% [markdown]
# ### Checking Pandas Version
# The version string is stored under __version__ attribute.

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# ## Import to CSV

# %%
df.to_csv('dataset.csv')

# %% [markdown]
# ## Remove Index

# %%
df.to_csv('pythonMondayRemoveIndex.csv', index=False)

# %% [markdown]
# ## Show some rows from the Start

# %%
df.head()
# Out:
#             Name Registration Number   GPA
# 0     Ahmed Khan        21jzele04230  3.22
# 1    Fatima Noor        21jzele04231  2.15
# 2   Mohammad Ali        21jzele04232  2.74
# 3  Ayesha Siddiq        21jzele04233  3.34
# 4    Hassan Raza        21jzele04234   2.8

# %%
df.tail(3)
# Out:
#              Name Registration Number   GPA
# 12   Ibrahim Zaid        21jzele04242  2.15
# 13     Nimra Shah        21jzele04243  2.07
# 14  Suleman Iqbal        21jzele04244   3.3

# %%
df.tail()
# Out:
#              Name Registration Number   GPA
# 10    Yusuf Jamal        21jzele04240  2.01
# 11    Hafsa Tariq        21jzele04241  2.33
# 12   Ibrahim Zaid        21jzele04242  2.15
# 13     Nimra Shah        21jzele04243  2.07
# 14  Suleman Iqbal        21jzele04244   3.3

# %%
df.describe()
# Out:
#               Name Registration Number   GPA
# count           15                  15    15
# unique          15                  15    13
# top     Ahmed Khan        21jzele04230  2.15
# freq             1                   1     3

# %%
# 10          10     Yusuf Jamal        21jzele04240  2.01
# 11          11     Hafsa Tariq        21jzele04241  2.33
# 12          12    Ibrahim Zaid        21jzele04242  2.15
# 13          13      Nimra Shah        21jzele04243  2.07
# 14          14   Suleman Iqbal        21jzele04244  3.30

# %%
classData['GPA']
# Out:
# 0     3.22
# 1     2.15
# 2     2.74
# 3     3.34
# 4     2.80
# 5     2.60
# 6     3.61
# 7     3.25
# 8     2.14
# 9     2.15
# 10    2.01
# 11    2.33
# 12    2.15
# 13    2.07
# 14    3.30
# Name: GPA, dtype: float64

# %%
classData['Name']
# Out:
# 0         Ahmed Khan
# 1        Fatima Noor
# 2       Mohammad Ali
# 3      Ayesha Siddiq
# 4        Hassan Raza
# 5      Zainab Sheikh
# 6        Umar Farooq
# 7        Maryam Bibi
# 8        Bilal Saeed
# 9     Khadija Rehman
# 10       Yusuf Jamal
# 11       Hafsa Tariq
# 12      Ibrahim Zaid
# 13        Nimra Shah
# 14     Suleman Iqbal
# Name: Name, dtype: object

# %%
classData['Registration Number']
# Out:
# 0     21jzele04230
# 1     21jzele04231
# 2     21jzele04232
# 3     21jzele04233
# 4     21jzele04234
# 5     21jzele04235
# 6     21jzele04236
# 7     21jzele04237
# 8     21jzele04238
# 9     21jzele04239
# 10    21jzele04240
# 11    21jzele04241
# 12    21jzele04242
# 13    21jzele04243
# 14    21jzele04244
# Name: Registration Number, dtype: object

# %%
type(classData['Name'])
# Out:
# pandas.core.series.Series

# %%
classData['GPA'][0]
# Out:
# np.float64(3.22)

# %%
classData['GPA'][0]=90
# Out:
# C:\Users\SIS\AppData\Local\Temp\ipykernel_1572\546375960.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   classData['GPA'][0]=90

# %%
classData
# Out:
#     Unnamed: 0            Name Registration Number    GPA
# 0            0      Ahmed Khan        21jzele04230  90.00
# 1            1     Fatima Noor        21jzele04231   2.15
# 2            2    Mohammad Ali        21jzele04232   2.74
# 3            3   Ayesha Siddiq        21jzele04233   3.34
# 4            4     Hassan Raza        21jzele04234   2.80
# 5            5   Zainab Sheikh        21jzele04235   2.60
# 6            6     Umar Farooq        21jzele04236   3.61
# 7            7     Maryam Bibi        21jzele04237   3.25
# 8            8     Bilal Saeed        21jzele04238   2.14
# 9            9  Khadija Rehman        21jzele04239   2.15
# 10          10     Yusuf Jamal        21jzele04240   2.01
# 11          11     Hafsa Tariq        21jzele04241   2.33
# 12          12    Ibrahim Zaid        21jzele04242   2.15
# 13          13      Nimra Shah        21jzele04243   2.07
# 14          14   Suleman Iqbal        21jzele04244   3.30

# %%
classData['GPA'][4]
# Out:
# np.float64(2.8)

# %%
classData['GPA'][4]=5
# Out:
# C:\Users\SIS\AppData\Local\Temp\ipykernel_1572\590528565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   classData['GPA'][4]=5

# %%
classData["Registration Number"][4]="21jzele04233"
# Out:
# C:\Users\SIS\AppData\Local\Temp\ipykernel_1572\652201625.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   classData["Registration Number"][4]="21jzele04233"

# %%
classData
# Out:
#     Unnamed: 0            Name Registration Number    GPA
# 0            0      Ahmed Khan        21jzele04230  90.00
# 1            1     Fatima Noor        21jzele04231   2.15
# 2            2    Mohammad Ali        21jzele04232   2.74
# 3            3   Ayesha Siddiq        21jzele04233   3.34
# 4            4     Hassan Raza        21jzele04233   5.00
# 5            5   Zainab Sheikh        21jzele04235   2.60
# 6            6     Umar Farooq        21jzele04236   3.61
# 7            7     Maryam Bibi        21jzele04237   3.25
# 8            8     Bilal Saeed        21jzele04238   2.14
# 9            9  Khadija Rehman        21jzele04239   2.15
# 10          10     Yusuf Jamal        21jzele04240   2.01
# 11          11     Hafsa Tariq        21jzele04241   2.33
# 12          12    Ibrahim Zaid        21jzele04242   2.15
# 13          13      Nimra Shah        21jzele04243   2.07
# 14          14   Suleman Iqbal        21jzele04244   3.30

# %%
classData["Name"][4]
# Out:
# 'Hassan Raza'

# %%
classData
# Out:
#     Unnamed: 0            Name Registration Number    GPA
# 0            0      Ahmed Khan        21jzele04230  90.00
# 1            1     Fatima Noor        21jzele04231   2.15
# 2            2    Mohammad Ali        21jzele04232   2.74
# 3            3   Ayesha Siddiq        21jzele04233   3.34
# 4            4     Hassan Raza        21jzele04233   5.00
# 5            5   Zainab Sheikh        21jzele04235   2.60
# 6            6     Umar Farooq        21jzele04236   3.61
# 7            7     Maryam Bibi        21jzele04237   3.25
# 8            8     Bilal Saeed        21jzele04238   2.14
# 9            9  Khadija Rehman        21jzele04239   2.15
# 10          10     Yusuf Jamal        21jzele04240   2.01
# 11          11     Hafsa Tariq        21jzele04241   2.33
# 12          12    Ibrahim Zaid        21jzele04242   2.15
# 13          13      Nimra Shah        21jzele04243   2.07
# 14          14   Suleman Iqbal        21jzele04244   3.30

# %%
classData.to_csv('pythonMonday.csv')

# %%
classData.to_csv('pythonMondayRemoveIndex.csv', index=False)

# %% [markdown]
# ## Create Labels
# With the index argument, you can name your own labels.

# %%
classData.index = ["21jzele04230","21jzele04231","21jzele04232","21jzele04233","21jzele04234",
                             "21jzele04235","21jzele04236","21jzele04237","21jzele04238","21jzele04239",
                             "21jzele04240","21jzele04241","21jzele04242","21jzele04243","21jzele04244"]

# %%
classData
# Out:
#               Unnamed: 0            Name Registration Number    GPA
# 21jzele04230           0      Ahmed Khan        21jzele04230  90.00
# 21jzele04231           1     Fatima Noor        21jzele04231   2.15
# 21jzele04232           2    Mohammad Ali        21jzele04232   2.74
# 21jzele04233           3   Ayesha Siddiq        21jzele04233   3.34
# 21jzele04234           4     Hassan Raza        21jzele04233   5.00
# 21jzele04235           5   Zainab Sheikh        21jzele04235   2.60
# 21jzele04236           6     Umar Farooq        21jzele04236   3.61
# 21jzele04237           7     Maryam Bibi        21jzele04237   3.25
# 21jzele04238           8     Bilal Saeed        21jzele04238   2.14
# 21jzele04239           9  Khadija Rehman        21jzele04239   2.15
# 21jzele04240          10     Yusuf Jamal        21jzele04240   2.01
# 21jzele04241          11     Hafsa Tariq        21jzele04241   2.33
# 21jzele04242          12    Ibrahim Zaid        21jzele04242   2.15
# 21jzele04243          13      Nimra Shah        21jzele04243   2.07
# 21jzele04244          14   Suleman Iqbal        21jzele04244   3.30

# %%
classData["Name"]["21jzele04236"]
# Out:
# 'Umar Farooq'

# %% [markdown]
# ## Pandas
# Pandas is an open source data analysis library written in Python.<br>
# It uses the power and speed of numpy to make data analysis and preprocessing easy for data scientists.<br>
# __Pandas__ is used to analyze data.<br>
# Python data analysis using pandas is a great start to Exploratory Data Analysis (EDA) for a data scientist.

# %% [markdown]
# ## Pandas Data Structure
# Panda has two types of Data Structure:<br>
#     a) Series<br>
#     b) Dataframe
# ### Series
# It is a one dimentional array with indexes. It stores a single column or row of data in a Dataframe.<br>
# It is a one dimensional array capable of holding any type of data.
# ### Dataframe
# It is a tabular spreadsheet like structure representing rows each of which contains one or more columns.<br>
# It is a multi dimensional array capable of holding any type of data.<br>
# __Series__ is like a column, a __DataFrame__ is the whole table.

# %%
classData['GPA']
# Out:
# 21jzele04230    90.00
# 21jzele04231     2.15
# 21jzele04232     2.74
# 21jzele04233     3.34
# 21jzele04234     5.00
# 21jzele04235     2.60
# 21jzele04236     3.61
# 21jzele04237     3.25
# 21jzele04238     2.14
# 21jzele04239     2.15
# 21jzele04240     2.01
# 21jzele04241     2.33
# 21jzele04242     2.15
# 21jzele04243     2.07
# 21jzele04244     3.30
# Name: GPA, dtype: float64

# %%
type(classData['GPA'])
# Out:
# pandas.core.series.Series

# %%
classData
# Out:
#               Unnamed: 0            Name Registration Number    GPA
# 21jzele04230           0      Ahmed Khan        21jzele04230  90.00
# 21jzele04231           1     Fatima Noor        21jzele04231   2.15
# 21jzele04232           2    Mohammad Ali        21jzele04232   2.74
# 21jzele04233           3   Ayesha Siddiq        21jzele04233   3.34
# 21jzele04234           4     Hassan Raza        21jzele04233   5.00
# 21jzele04235           5   Zainab Sheikh        21jzele04235   2.60
# 21jzele04236           6     Umar Farooq        21jzele04236   3.61
# 21jzele04237           7     Maryam Bibi        21jzele04237   3.25
# 21jzele04238           8     Bilal Saeed        21jzele04238   2.14
# 21jzele04239           9  Khadija Rehman        21jzele04239   2.15
# 21jzele04240          10     Yusuf Jamal        21jzele04240   2.01
# 21jzele04241          11     Hafsa Tariq        21jzele04241   2.33
# 21jzele04242          12    Ibrahim Zaid        21jzele04242   2.15
# 21jzele04243          13      Nimra Shah        21jzele04243   2.07
# 21jzele04244          14   Suleman Iqbal        21jzele04244   3.30

# %%
type(classData)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy as np

# %%
series1= pd.Series(np.random.rand())

# %%
series1
# Out:
# 0    0.335689
# dtype: float64

# %%
series1= pd.Series(np.random.rand(30))

# %%
series1
# Out:
# 0     0.495977
# 1     0.339018
# 2     0.541635
# 3     0.782049
# 4     0.978042
# 5     0.965704
# 6     0.037828
# 7     0.990482
# 8     0.105786
# 9     0.845349
# 10    0.511609
# 11    0.754078
# 12    0.823500
# 13    0.256488
# 14    0.845410
# 15    0.518937
# 16    0.625102
# 17    0.563880
# 18    0.397868
# 19    0.102082
# 20    0.995979
# 21    0.213363
# 22    0.205612
# 23    0.192203
# 24    0.187762
# 25    0.098982
# 26    0.279974
# 27    0.511944
# 28    0.804962
# 29    0.618942
# dtype: float64

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
newDf = pd.DataFrame(np.random.rand(330,5))
# newDf = pd.DataFrame(np.random.rand(330,5), index=np.arange(330))

# %%
type(newDf)
# Out:
# pandas.core.frame.DataFrame

# %%
newDf
# Out:
#             0         1         2         3         4
# 0    0.678488  0.549143  0.649358  0.257886  0.796377
# 1    0.955498  0.165255  0.875604  0.567691  0.431945
# 2    0.240486  0.875688  0.961548  0.013515  0.532565
# 3    0.297215  0.724736  0.549661  0.418684  0.518788
# 4    0.919132  0.246184  0.528773  0.692460  0.453191
# ..        ...       ...       ...       ...       ...
# 325  0.457648  0.984963  0.041711  0.300133  0.947789
# 326  0.114971  0.832981  0.872131  0.118775  0.900151
# 327  0.061987  0.558319  0.082750  0.973201  0.084270
# 328  0.618785  0.031342  0.767001  0.645786  0.840079
# 329  0.473104  0.175221  0.568719  0.982632  0.496613
#
# [330 rows x 5 columns]

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0  0.678488  0.549143  0.649358  0.257886  0.796377
# 1  0.955498  0.165255  0.875604  0.567691  0.431945

# %%
newDf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newDf.tail(2)
# Out:
#             0         1         2         3         4
# 328  0.618785  0.031342  0.767001  0.645786  0.840079
# 329  0.473104  0.175221  0.568719  0.982632  0.496613

# %%
newDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       330 non-null    float64
#  1   1       330 non-null    float64
#  2   2       330 non-null    float64
#  3   3       330 non-null    float64
#  4   4       330 non-null    float64
# dtypes: float64(5)
# memory usage: 13.0 KB

# %%
newDf.describe()
# Out:
#                 0           1           2           3           4
# count  330.000000  330.000000  330.000000  330.000000  330.000000
# mean     0.496435    0.505353    0.506118    0.522719    0.503184
# std      0.293631    0.303027    0.293975    0.293303    0.300293
# min      0.007158    0.002412    0.011543    0.000382    0.001890
# 25%      0.248750    0.232910    0.263000    0.266447    0.238952
# 50%      0.509366    0.503648    0.489627    0.527256    0.506415
# 75%      0.758273    0.773082    0.787799    0.778900    0.771970
# max      0.999573    0.998829    0.999023    0.998482    0.999203

# %%
newDf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newDf[0][0]= "Maaz Khan"
# Out:
# C:\Users\SIS\AppData\Local\Temp\ipykernel_1572\4095004716.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDf[0][0]= "Maaz Khan"
# C:\Users\SIS\AppData\Local\Temp\ipykernel_1572\4095004716.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Maaz Khan' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   newDf[0][0]= "Maaz Khan"

# %%
newDf.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newDf
# Out:
#              0         1         2         3         4
# 0    Maaz Khan  0.549143  0.649358  0.257886  0.796377
# 1     0.955498  0.165255  0.875604  0.567691  0.431945
# 2     0.240486  0.875688  0.961548  0.013515  0.532565
# 3     0.297215  0.724736  0.549661  0.418684  0.518788
# 4     0.919132  0.246184  0.528773  0.692460  0.453191
# ..         ...       ...       ...       ...       ...
# 325   0.457648  0.984963  0.041711  0.300133  0.947789
# 326   0.114971  0.832981  0.872131  0.118775  0.900151
# 327   0.061987  0.558319  0.082750  0.973201  0.084270
# 328   0.618785  0.031342  0.767001  0.645786  0.840079
# 329   0.473104  0.175221  0.568719  0.982632  0.496613
#
# [330 rows x 5 columns]

# %%
newDf.index
# Out:
# RangeIndex(start=0, stop=330, step=1)

# %%
newDf.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# 325  0.457648  0.984963  0.041711  0.300133  0.947789
# 326  0.114971  0.832981  0.872131  0.118775  0.900151
# 327  0.061987  0.558319  0.082750  0.973201  0.084270
# 328  0.618785  0.031342  0.767001  0.645786  0.840079
# 329  0.473104  0.175221  0.568719  0.982632  0.496613
#
# [330 rows x 5 columns]

# %%
newDfView[0][0]=765
# Out:
# C:\Users\SIS\AppData\Local\Temp\ipykernel_1572\4063526219.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDfView[0][0]=765
# C:\Users\SIS\AppData\Local\Temp\ipykernel_1572\4063526219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDfView[0][0]=765

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0       765  0.549143  0.649358  0.257886  0.796377
# 1  0.955498  0.165255  0.875604  0.567691  0.431945
# 2  0.240486  0.875688  0.961548  0.013515  0.532565
# 3  0.297215  0.724736  0.549661  0.418684  0.518788
# 4  0.919132  0.246184  0.528773  0.692460  0.453191

# %%
newDfView.head()
# Out:
#           0         1         2         3         4
# 0       765  0.549143  0.649358  0.257886  0.796377
# 1  0.955498  0.165255  0.875604  0.567691  0.431945
# 2  0.240486  0.875688  0.961548  0.013515  0.532565
# 3  0.297215  0.724736  0.549661  0.418684  0.518788
# 4  0.919132  0.246184  0.528773  0.692460  0.453191

# %%
newDfCopy=newDf.copy()

# %%
newDfCopy[0][0]=656
# Out:
# C:\Users\SIS\AppData\Local\Temp\ipykernel_1572\2532441962.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDfCopy[0][0]=656
# C:\Users\SIS\AppData\Local\Temp\ipykernel_1572\2532441962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDfCopy[0][0]=656

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0       765  0.549143  0.649358  0.257886  0.796377
# 1  0.955498  0.165255  0.875604  0.567691  0.431945
# 2  0.240486  0.875688  0.961548  0.013515  0.532565
# 3  0.297215  0.724736  0.549661  0.418684  0.518788
# 4  0.919132  0.246184  0.528773  0.692460  0.453191

# %%
newDfCopy.head()
# Out:
#           0         1         2         3         4
# 0       656  0.549143  0.649358  0.257886  0.796377
# 1  0.955498  0.165255  0.875604  0.567691  0.431945
# 2  0.240486  0.875688  0.961548  0.013515  0.532565
# 3  0.297215  0.724736  0.549661  0.418684  0.518788
# 4  0.919132  0.246184  0.528773  0.692460  0.453191

# %% [markdown]
# ## loc

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0       765  0.549143  0.649358  0.257886  0.796377
# 1  0.955498  0.165255  0.875604  0.567691  0.431945

# %%
newDf.loc[0,0]
# Out:
# 765

# %%
newDf.loc[0,0]=5678

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0      5678  0.549143  0.649358  0.257886  0.796377
# 1  0.955498  0.165255  0.875604  0.567691  0.431945

# %%
newDf.loc[0,4]
# Out:
# np.float64(0.7963772766795659)

# %%
newDf.loc[325,1]
# Out:
# np.float64(0.9849626644316151)

# %%
newDf.loc[0,0]=9875

# %%
newDf.head(2)
# Out:
#           0         1         2         3         4
# 0      9875  0.549143  0.649358  0.257886  0.796377
# 1  0.955498  0.165255  0.875604  0.567691  0.431945

# %%
newDf.columns=list("ABCDE")

# %%
newDf.head(3)
# Out:
#           A         B         C         D         E
# 0      9875  0.549143  0.649358  0.257886  0.796377
# 1  0.955498  0.165255  0.875604  0.567691  0.431945
# 2  0.240486  0.875688  0.961548  0.013515  0.532565

# %%
newDf.loc[0, "A"]
# Out:
# 9875

# %%
newDf.loc[0,"A"]=65

# %%
newDf.head(3)
# Out:
#           A         B         C         D         E
# 0        65  0.549143  0.649358  0.257886  0.796377
# 1  0.955498  0.165255  0.875604  0.567691  0.431945
# 2  0.240486  0.875688  0.961548  0.013515  0.532565

# %%
newDf.loc[35,"A"]
# Out:
# 0.8558985455484028

# %%
newDf.drop(0, axis=0).head(3)
# Out:
#           A         B         C         D         E
# 1  0.955498  0.165255  0.875604  0.567691  0.431945
# 2  0.240486  0.875688  0.961548  0.013515  0.532565
# 3  0.297215  0.724736  0.549661  0.418684  0.518788

# %%
newDf.drop("A", axis=1).head(3)
# Out:
#           B         C         D         E
# 0  0.549143  0.649358  0.257886  0.796377
# 1  0.165255  0.875604  0.567691  0.431945
# 2  0.875688  0.961548  0.013515  0.532565

# %%
newDf.head(3)
# Out:
#           A         B         C         D         E
# 0        65  0.549143  0.649358  0.257886  0.796377
# 1  0.955498  0.165255  0.875604  0.567691  0.431945
# 2  0.240486  0.875688  0.961548  0.013515  0.532565

# %%
newDf = newDf.drop("A", axis=1)

# %%
newDf.head(3)
# Out:
#           B         C         D         E
# 0  0.549143  0.649358  0.257886  0.796377
# 1  0.165255  0.875604  0.567691  0.431945
# 2  0.875688  0.961548  0.013515  0.532565

# %%
newDf.loc[[1,2],["C","D"]]
# Out:
#           C         D
# 1  0.875604  0.567691
# 2  0.961548  0.013515

# %%
newDf.head(3)
# Out:
#           B         C         D         E
# 0  0.549143  0.649358  0.257886  0.796377
# 1  0.165255  0.875604  0.567691  0.431945
# 2  0.875688  0.961548  0.013515  0.532565

# %%
newDf.loc[:,["C","D"]]
# Out:
#             C         D
# 0    0.649358  0.257886
# 1    0.875604  0.567691
# 2    0.961548  0.013515
# 3    0.549661  0.418684
# 4    0.528773  0.692460
# ..        ...       ...
# 325  0.041711  0.300133
# 326  0.872131  0.118775
# 327  0.082750  0.973201
# 328  0.767001  0.645786
# 329  0.568719  0.982632
#
# [330 rows x 2 columns]

# %%
newDf.loc[[1,2],:]
# Out:
#           B         C         D         E
# 1  0.165255  0.875604  0.567691  0.431945
# 2  0.875688  0.961548  0.013515  0.532565

# %%
newDf.loc[:5,["C","D"]]
# Out:
#           C         D
# 0  0.649358  0.257886
# 1  0.875604  0.567691
# 2  0.961548  0.013515
# 3  0.549661  0.418684
# 4  0.528773  0.692460
# 5  0.841982  0.322560

# %%
newDf.loc[[1,2],:"D"]
# Out:
#           B         C         D
# 1  0.165255  0.875604  0.567691
# 2  0.875688  0.961548  0.013515

# %%
newDf.loc[(newDf["B"]<0.3)]
# Out:
#             B         C         D         E
# 1    0.165255  0.875604  0.567691  0.431945
# 4    0.246184  0.528773  0.692460  0.453191
# 5    0.076591  0.841982  0.322560  0.986561
# 10   0.114851  0.962170  0.865406  0.110492
# 13   0.265619  0.319709  0.636971  0.974001
# ..        ...       ...       ...       ...
# 307  0.025199  0.064264  0.906063  0.440877
# 308  0.192300  0.498070  0.362614  0.029759
# 312  0.164881  0.217009  0.558420  0.102306
# 328  0.031342  0.767001  0.645786  0.840079
# 329  0.175221  0.568719  0.982632  0.496613
#
# [107 rows x 4 columns]

# %%
newDf.loc[(newDf["B"]<0.3) & (newDf["D"]>0.2)]
# Out:
#             B         C         D         E
# 1    0.165255  0.875604  0.567691  0.431945
# 4    0.246184  0.528773  0.692460  0.453191
# 5    0.076591  0.841982  0.322560  0.986561
# 10   0.114851  0.962170  0.865406  0.110492
# 13   0.265619  0.319709  0.636971  0.974001
# ..        ...       ...       ...       ...
# 307  0.025199  0.064264  0.906063  0.440877
# 308  0.192300  0.498070  0.362614  0.029759
# 312  0.164881  0.217009  0.558420  0.102306
# 328  0.031342  0.767001  0.645786  0.840079
# 329  0.175221  0.568719  0.982632  0.496613
#
# [95 rows x 4 columns]

# %%
newDf.head(3)
# Out:
#           B         C         D         E
# 0  0.549143  0.649358  0.257886  0.796377
# 1  0.165255  0.875604  0.567691  0.431945
# 2  0.875688  0.961548  0.013515  0.532565

# %% [markdown]
# ## iloc

# %%
newDf.iloc[0,0]
# Out:
# np.float64(0.5491427968147892)

# %%
newDf.iloc[0,0]=555

# %%
newDf.head()
# Out:
#             B         C         D         E
# 0  555.000000  0.649358  0.257886  0.796377
# 1    0.165255  0.875604  0.567691  0.431945
# 2    0.875688  0.961548  0.013515  0.532565
# 3    0.724736  0.549661  0.418684  0.518788
# 4    0.246184  0.528773  0.692460  0.453191

# %%
newDf.iloc[[0,4],[1,3]]
# Out:
#           C         E
# 0  0.649358  0.796377
# 4  0.528773  0.453191

# %%
newDf.head(4)
# Out:
#             B         C         D         E
# 0  555.000000  0.649358  0.257886  0.796377
# 1    0.165255  0.875604  0.567691  0.431945
# 2    0.875688  0.961548  0.013515  0.532565
# 3    0.724736  0.549661  0.418684  0.518788

# %%
newDf.drop(0).head()
# Out:
#           B         C         D         E
# 1  0.165255  0.875604  0.567691  0.431945
# 2  0.875688  0.961548  0.013515  0.532565
# 3  0.724736  0.549661  0.418684  0.518788
# 4  0.246184  0.528773  0.692460  0.453191
# 5  0.076591  0.841982  0.322560  0.986561

# %%
# newDf.drop(0, axis=1)

# %%
# newDf.drop("B", axis=1).head()

# %%
newDf.drop(["C", "D"], axis=1).head()
# Out:
#             B         E
# 0  555.000000  0.796377
# 1    0.165255  0.431945
# 2    0.875688  0.532565
# 3    0.724736  0.518788
# 4    0.246184  0.453191

# %%
newDf.head()
# Out:
#             B         C         D         E
# 0  555.000000  0.649358  0.257886  0.796377
# 1    0.165255  0.875604  0.567691  0.431945
# 2    0.875688  0.961548  0.013515  0.532565
# 3    0.724736  0.549661  0.418684  0.518788
# 4    0.246184  0.528773  0.692460  0.453191

# %%
newDf.drop(['B', 'D'], axis=1, inplace=True)

# %%
newDf.head()
# Out:
#           C         E
# 0  0.649358  0.796377
# 1  0.875604  0.431945
# 2  0.961548  0.532565
# 3  0.549661  0.518788
# 4  0.528773  0.453191

# %%
newDf.reset_index().head()
# Out:
#    index         C         E
# 0      0  0.649358  0.796377
# 1      1  0.875604  0.431945
# 2      2  0.961548  0.532565
# 3      3  0.549661  0.518788
# 4      4  0.528773  0.453191

# %%
newDf.reset_index(drop=True).head()
# Out:
#           C         E
# 0  0.649358  0.796377
# 1  0.875604  0.431945
# 2  0.961548  0.532565
# 3  0.549661  0.518788
# 4  0.528773  0.453191

# %%
newDf.head()
# Out:
#           C         E
# 0  0.649358  0.796377
# 1  0.875604  0.431945
# 2  0.961548  0.532565
# 3  0.549661  0.518788
# 4  0.528773  0.453191

# %%
newDf.reset_index(drop=True, inplace=True)

# %%
newDf.head()
# Out:
#           C         E
# 0  0.649358  0.796377
# 1  0.875604  0.431945
# 2  0.961548  0.532565
# 3  0.549661  0.518788
# 4  0.528773  0.453191

# %% [markdown]
# # Groupby
# The groupby method allows you to group rows of data together and call aggregate functions
#
# ​
# ​

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# ### Now you can use the .groupby() method to group rows together based off of a column name.
# For instance let's group based off of Company. This will create a DataFrameGroupBy object:

# %%
df.groupby('Company')

# %% [markdown]
# ##### You can save this object as a new variable:

# %%
by_comp = df.groupby("Company")
type(by_comp)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# #### And then call aggregate methods of the object:

# %%
by_comp.mean("sale")
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
df.groupby("Company")

# %%
df.select_dtypes(include='number').groupby(df['Company']).std()
# Out:
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0
